# %% [markdown]
# # Imports & Setup

# %%
import pandas as pd
import numpy as np
import re

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/akshatsoni/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/akshatsoni/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/akshatsoni/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#laod file
df = pd.read_csv("AFE.csv")

# %%
df[['Narrative', 'Root_Cause_Keywords']].head()
# Out:
#                                            Narrative  \
# 0  Pump failed to respond, irregular cycling obse...
# 1  Compressor cycling irregularly; passenger disc...
# 2  Bus Tie fault reported; unexpected shutdown le...
# 3  Reports of checklist execution due to Ventilat...
# 4  Flight  Computer  produced  erroneous  reading...
#
#          Root_Cause_Keywords
# 0            pump, hydraulic
# 1            compressor, a/c
# 2        bus_tie, electrical
# 3       ventilation_fan, a/c
# 4  flight_computer, avionics

# %% [markdown]
# ## Basic Text Cleaning

# %%
# initial tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# cleaning function
def clean_text(text):
    if pd.isna(text):
        return ""
    
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) 
              for word in tokens 
              if word not in stop_words and len(word) > 2]
    
    return " ".join(tokens)

# %%
#testing the function
clean_text(df['Narrative'].iloc[1])
# Out:
# 'compressor cycling irregularly passenger discomfort passenger discomfort climb'

# %%
#create anothe col named clean_narr..
df['Clean_Narrative'] = df['Narrative'].apply(clean_text)

# %%
df[['Narrative', 'Clean_Narrative']].sample(10)
# Out:
#                                                 Narrative  \
# 118954  Electrical smell and short circuit near Batter...
# 89269   Bus Tie fault reported; irregular cycling led ...
# 42294   AC/heating issue: Ventilation Fan pressure los...
# 86366   Power Bus fault reported; voltage drop led to ...
# 150187  Reports of avionics warning due to Ventilation...
# 93833   Crew noted reduced thrust after Wiring Harness...
# 7254    Brake Unit actuator showed voltage drop during...
# 104421  During Descent, Wiring Harness experienced flu...
# 145192  Crew noted manual reset after Bus Tie showed f...
# 68166   Battery fault reported; unexpected shutdown le...
#
#                                           Clean_Narrative
# 118954  electrical smell short circuit near battery ma...
# 89269   bus tie fault reported irregular cycling led c...
# 42294   heating issue ventilation fan pressure loss cr...
# 86366   power bus fault reported voltage drop led avio...
# 150187  report avionics warning due ventilation fan pr...
# 93833   crew noted reduced thrust wiring harness showe...
# 7254    brake unit actuator showed voltage drop descen...
# 104421  descent wiring harness experienced fluctuation...
# 145192  crew noted manual reset bus tie showed fluctua...
# 68166   battery fault reported unexpected shutdown led...

# %% [markdown]
# ## Domain Keyword Normalization

# %%
FAULT_VOCAB = {
    'electrical': {
        'wire', 'wiring', 'cable', 'connector', 'short', 'shorting',
        'electrical', 'power', 'bus', 'circuit', 'breaker', 'voltage'
    },
    'air_conditioning': {
        'ac', 'air', 'conditioning', 'cooling', 'ventilation',
        'pressurization', 'temperature', 'bleed'
    },
    'hydraulic': {
        'hydraulic', 'fluid', 'leak', 'pressure', 'actuator', 'pump', 'valve'
    },
    'engine': {
        'engine', 'turbine', 'compressor', 'fan', 'rpm', 'vibration'
    },
    'sensor': {
        'sensor', 'probe', 'indicator', 'warning', 'fault', 'signal'
    }
}
#keywords map

# %%
# tokenizer helper
def tokenize(text):
    if not text:
        return set()
    return set(text.split())

# %%
def score_fault_type(clean_text):
    tokens = tokenize(clean_text)
    
    scores = {}
    for fault_type, vocab in FAULT_VOCAB.items():
        scores[fault_type] = len(tokens.intersection(vocab))
    
    # pick highest scoring fault type
    best_fault = max(scores, key=scores.get)
    
    # confidence threshold (VERY IMPORTANT)
    if scores[best_fault] >= 2:
        return best_fault
    else:
        return 'other'

# %%
df['Primary_Fault_Type'] = df['Clean_Narrative'].apply(score_fault_type)

# %%
df['Primary_Fault_Type'].value_counts()
# Out:
# Primary_Fault_Type
# other         100625
# electrical     35639
# hydraulic       9281
# sensor          4755
# Name: count, dtype: int64

# %%
df['Clean_Root_Cause'] = df['Root_Cause_Keywords'].apply(clean_text)

# %%
def consistency_check(row):
    if row['Primary_Fault_Type'] == 'other':
        return 0
    
    root_tokens = tokenize(row['Clean_Root_Cause'])
    fault_vocab = FAULT_VOCAB.get(row['Primary_Fault_Type'], set())
    
    return int(len(root_tokens.intersection(fault_vocab)) >= 1)

# %%
df['Consistency_Flag'] = df.apply(consistency_check, axis=1)

# %%
consistency_score = df['Consistency_Flag'].mean()*100
consistency_score
# Out:
# 56.5395874916833

# %%
df.groupby('Primary_Fault_Type')['Consistency_Flag'].mean().sort_values(ascending=False)
# Out:
# Primary_Fault_Type
# hydraulic     0.939662
# electrical    0.829232
# sensor        0.613249
# other         0.000000
# Name: Consistency_Flag, dtype: float64

# %%
df
# Out:
#         Report_ID        Date Aircraft_Make Aircraft_Model Flight_Phase  \
# 0         4059770  2021-01-18        Airbus           A350       Cruise
# 1         4021362  2016-07-03       Embraer           E190        Climb
# 2         4127324  2010-09-01        Airbus           A320        Climb
# 3         4140509  2024-10-25        Boeing        777-300         Taxi
# 4         4144297  2024-04-19           ATR          ATR72      Landing
# ...           ...         ...           ...            ...          ...
# 150295    4040287  2017-03-21        Airbus           A330       Cruise
# 150296    4022943  2011-11-16       Embraer           E175       Cruise
# 150297    4012699  2023-07-20           ATR          ATR72      Descent
# 150298    4086513  2010-02-06    Bombardier           Q400      Descent
# 150299    4040552  2023-11-10        Airbus           A330       Cruise
#
#                      System           Component  Severity Location  \
# 0                 Hydraulic                Pump       Low       NJ
# 1       A/C (Environmental)          Compressor  Moderate       GA
# 2                Electrical             Bus Tie       Low       AZ
# 3       A/C (Environmental)     Ventilation Fan  Moderate       MD
# 4                  Avionics     Flight Computer       Low       CO
# ...                     ...                 ...       ...      ...
# 150295           Electrical     Circuit Breaker       Low       NJ
# 150296           Electrical             Bus Tie  Moderate       IL
# 150297  A/C (Environmental)  Temperature Sensor       Low       MD
# 150298           Electrical     Circuit Breaker       Low       TX
# 150299            Hydraulic      Hydraulic Line  Moderate       FL
#
#                                                 Narrative  \
# 0       Pump failed to respond, irregular cycling obse...
# 1       Compressor cycling irregularly; passenger disc...
# 2       Bus Tie fault reported; unexpected shutdown le...
# 3       Reports of checklist execution due to Ventilat...
# 4       Flight  Computer  produced  erroneous  reading...
# ...                                                   ...
# 150295  Circuit Breaker fault reported; irregular cycl...
# 150296  During Cruise, Bus Tie experienced leak, crew ...
# 150297  Temperature Sensor cycling irregularly; avioni...
# 150298  During Descent, Circuit Breaker experienced sh...
# 150299  Hydraulic Line failed to respond, leak observe...
#
#                 Root_Cause_Keywords  Model_Age  \
# 0                   pump, hydraulic         14
# 1                   compressor, a/c         21
# 2               bus_tie, electrical         25
# 3              ventilation_fan, a/c         30
# 4         flight_computer, avionics         29
# ...                             ...        ...
# 150295  circuit_breaker, electrical         21
# 150296          bus_tie, electrical          7
# 150297      temperature_sensor, a/c         29
# 150298  circuit_breaker, electrical         13
# 150299    hydraulic_line, hydraulic         21
#
#                                           Clean_Narrative Primary_Fault_Type  \
# 0       pump failed respond irregular cycling observed...              other
# 1       compressor cycling irregularly passenger disco...              other
# 2       bus tie fault reported unexpected shutdown led...              other
# 3       report checklist execution due ventilation fan...              other
# 4       flight computer produced erroneous reading ove...              other
# ...                                                   ...                ...
# 150295  circuit breaker fault reported irregular cycli...         electrical
# 150296  cruise bus tie experienced leak crew observed ...              other
# 150297  temperature sensor cycling irregularly avionic...             sensor
# 150298  descent circuit breaker experienced short circ...         electrical
# 150299  hydraulic line failed respond leak observed cr...          hydraulic
#
#                   Clean_Root_Cause  Consistency_Flag
# 0                   pump hydraulic                 0
# 1                       compressor                 0
# 2               bus tie electrical                 0
# 3                  ventilation fan                 0
# 4         flight computer avionics                 0
# ...                            ...               ...
# 150295  circuit breaker electrical                 1
# 150296          bus tie electrical                 0
# 150297          temperature sensor                 1
# 150298  circuit breaker electrical                 1
# 150299    hydraulic line hydraulic                 1
#
# [150300 rows x 16 columns]

# %%
nlp_df = df[
    [
        'Report_ID',
        'System',
        'Component',
        'Flight_Phase',
        'Model_Age',
        'Severity',
        'Clean_Narrative',
        'Primary_Fault_Type'
    ]
]

nlp_df.to_csv("AFE_nlp.csv", index=False)

# %% [markdown]
# # NLP part is DoNe!
